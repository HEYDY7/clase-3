# %%
from pylab import plot, show
from math import exp

vnum=[]
time=[]
vana=[]

dt=1
g=9.8
m=68.1
c=12.5
vo=0

for t in range (21):
    
    vo=vi+((c/m)*vo-g)*dt
    v=(m*g/c)*(-exp(c*t/m)+1)
    
    vnum.append (vo)
    time.append (t)
    vana.append (v)
    
print(vnum) 
print(vana)

plot (time,vnum,'ob')
plot (time,vana,'g')
show
# Out:
# [-1794.6813042481592, -2124.1015142790257, -2184.567778968979, -2195.666579389308, -2197.7038041360647, -2198.0777440675542, -2198.1463820872846, -2198.1589808427416, -2198.1612933896317, -2198.161717865933, -2198.1617957800854, -2198.1618100815085, -2198.161812706586, -2198.1618131884284, -2198.161813276872, -2198.1618132931067, -2198.1618132960866, -2198.161813296633, -2198.1618132967337, -2198.1618132967524, -2198.1618132967556]
# [0.0, -10.757063630516617, -23.68145355847592, -39.209841299537686, -57.86687866693556, -80.28292398553863, -107.21533977218009, -139.57408145899151, -178.4524417163414, -225.1639891222885, -281.2869492115207, -348.71752738963824, -429.73397531408705, -527.0735653285319, -644.0250736570147, -784.5398970528946, -953.3655571591249, -1156.2061032416107, -1399.9148327626565, -1692.7258411722328, -2044.5322242030436]
# <function matplotlib.pyplot.show>
